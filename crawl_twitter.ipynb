# %% [markdown]
# <a href="https://colab.research.google.com/github/aditsnapz/crawltwittertes/blob/master/crawl_twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# stream twitter to csv
import tweepy
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import time
import json
access_token = "icp7ICDktRxSBiGwlA3UHyWaw"
access_token_secret ="0LRrbJ1A7vDB8JNgk6dEQwhPjXMyXBMRjbGVRHt5JvPLmim4xN"
consumer_key ="875482327-TcF4bgh7BpwJqH9tVzSrB9VUEmuLJFcXpYP1JvBl"
consumer_secret="z3kI5phiyprvt9QeuVzmHzstKeEfATg1AScZtyQTLaGyX"
class StdoutListener(StreamListener):
    def on_data(self,data):
        try:
            data = json.loads(data)
            tweet = data['text']
            print(tweet)
            with open('tweet.csv', 'a', encoding='utf-8') as f:
                saveFile = open('gabung.csv','a')
                f.write(tweet)
                f.write('\n')
                f.close()
            return True
        except BaseException as e:
            print('Failed'(e))
   
    def on_error(self,status):
        print(status)
#streaming
l = StdoutListener()
auth = OAuthHandler(access_token,access_token_secret)
auth.set_access_token(consumer_key, consumer_secret)
stream = Stream(auth,l)
stream.filter(track=['omnibuslaw'])
# Out:
# Prof Dr. Maria Sumardjono. Guru Besar UGM. Anggota Majelis Pakar KPA @SeknasKPA menjelaskan Omnibuslaw UU Cipta Ker… https://t.co/Tn4gwGfL2e
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d2cb75b2e25c> in <module>()
#      32 auth.set_access_token(consumer_key, consumer_secret)
#      33 stream = Stream(auth,l)
# ---> 34 stream.filter(track=['omnibuslaw'])
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     448         self.session.params = {'delimited': 'length'}
#     449         self.host = 'stream.twitter.com'
# --> 450         self._start(async)
#     451
#     452     def sitestream(self, follow, stall_warnings=False,
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in _start(self, async)
# ...

# %%
# search twitter
#!/usr/bin/python3
# coding=utf-8

# Import Library yang dibutuhkan
import tweepy
import csv
import pandas as pd

# Masukkan Twitter Token API
consumer_key = "icp7ICDktRxSBiGwlA3UHyWaw"
consumer_secret = "0LRrbJ1A7vDB8JNgk6dEQwhPjXMyXBMRjbGVRHt5JvPLmim4xN"
access_token = "875482327-TcF4bgh7BpwJqH9tVzSrB9VUEmuLJFcXpYP1JvBl"
access_token_secret = "z3kI5phiyprvt9QeuVzmHzstKeEfATg1AScZtyQTLaGyX"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# Buat path file CSV kedalam variabel
csvFile = open('dataset_search.csv', 'a')

# buat variabel baru untuk membuat file csv
csvWriter = csv.writer(csvFile)

# Mulai crawling search tweet
for tweet in tweepy.Cursor(api.search,q="#omnibuslaw",count=100,
                           lang="in",
                           since="2020-09-20").items():
    print (tweet.created_at, tweet.text)
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
# Out:
# Streaming output truncated to the last 5000 lines.
# @OmbudsmanRI137 #UUCiptaKerja #ciptakerja…
# 2020-10-17 13:46:03 UU Cipta Kerja penting untuk transformasi digital. Part. 2
# #OmnibusLaw
# #IndonesiaMaju https://t.co/O5ftbLT7n6
# 2020-10-17 13:44:52 RT @NCI4NKRI: UU Cipta Kerja penting untuk transformasi digital.
# #OmnibusLaw
# #IndonesiaMaju https://t.co/uxH0pZp6Gr
# 2020-10-17 13:43:38 UU Cipta Kerja penting untuk transformasi digital.
# #OmnibusLaw
# #IndonesiaMaju https://t.co/uxH0pZp6Gr
# 2020-10-17 13:40:32 RT @KlimaAction: Solidaritas Tanpa Batas
# #OmnibusLaw RUU CiptaKerja
# Siapa akan terkesan ?
#
# Dengarkan mengapa masyarakat sivil turun di j…
# 2020-10-17 13:29:44 Ini fakta yang benar dalam hoaks di Omnibus Law UU Ciptaker
# #OmnibusLaw https://t.co/7m0qlqnVOl
# 2020-10-17 13:28:52 RT @JogjaMandiSiang: penunggangnya banyak banget ya ??? masih mau demo ginian apa lanjut ke MK aja ??? #JogjaMemanggil #GejayanMemanggil #O…
# ...

# %%
# stream twitter in json format
#!/usr/bin/python3
# coding=utf-8

# Import library yang dibutuhkan
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import datetime
import csv

# Masukkan Twitter Token API
consumer_key = "icp7ICDktRxSBiGwlA3UHyWaw"
consumer_secret = "0LRrbJ1A7vDB8JNgk6dEQwhPjXMyXBMRjbGVRHt5JvPLmim4xN"
access_token = "875482327-TcF4bgh7BpwJqH9tVzSrB9VUEmuLJFcXpYP1JvBl"
access_token_secret = "z3kI5phiyprvt9QeuVzmHzstKeEfATg1AScZtyQTLaGyX"

# Buat class untuk stream
class StdOutListener(StreamListener):
    def on_status(self, status):
        # filter tweet yang berbahasa indonesia, kemudian masukkan kedalam csv
        if status.lang == "in":
            print(status)
            tweet_text = "'" + status.text.replace('\n', ' ') + "'"
            tweet_text = tweet_text.encode('utf-8')
            csvw.writerow([status.id,
                        status.user.screen_name,
                        status.created_at.strftime('%m/%d/%y'),
                        status.user.followers_count,
                        tweet_text])
            return True

    def on_error(self, status_code):
        # tampilkan pesan jika terdapat error koneksi
        if status_code == 420:
            print(status_code)
            return False


if __name__ == '__main__':

    # Handel twitter autentikasi dan koneksi streaming
    l = StdOutListener()
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    stream = Stream(auth, l)

    # Buat file csv dan filter stream dengan kata kunci
    csvw = csv.writer(open("dataset_stream.csv", "a"))
    csvw.writerow(['twitter_id', 'name', 'created_at', 'followers_count', 'text'])
    stream.filter(track=['dpr', 'omnibuslaw'])
# Out:
# Status(_api=<tweepy.api.API object at 0x7feabc050a20>, _json={'created_at': 'Mon Oct 19 09:08:13 +0000 2020', 'id': 1318116734776168449, 'id_str': '1318116734776168449', 'text': '@sintalv Mrka biasa mnyebutnya dgn istilh anggran prjamuan dri uang negara.\U0001f92d😁\nKalau Anggarn Mkn dan Jajanan Rapat D… https://t.co/0cA3QQVcVW', 'display_text_range': [9, 140], 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': 1318050313337667584, 'in_reply_to_status_id_str': '1318050313337667584', 'in_reply_to_user_id': 106351666, 'in_reply_to_user_id_str': '106351666', 'in_reply_to_screen_name': 'sintalv', 'user': {'id': 1634168696, 'id_str': '1634168696', 'name': 'Anto Kusmana', 'screen_name': 'AnthoKusmana', 'location': 'Kemayoran, Jakarta Indonesia', 'url': 'http://www.youtube.com/channel/UCRy44cj_397cL-WPZb1P_DQ', 'description': 'Sederhana..!!!!', 'translator_type': 'none', 'protected': False, 'verified'
# ...
